# %%
import LSST_treecorr as ltc

# %%
ltc.producecorrplots('/users/kasia/Documents/Fermilab/Code/LSST/LSST_i.fits', 0.98)

# %%
ltc.producecorrplots('/users/kasia/Documents/Fermilab/Code/LSST/LSST_i.fits', 0.98, 0.2, 0.4)

# %%
redshifts = [0.2, 0.4, 0.6, 0.8]
purities = [0.98, 0.7, 0.4]

"""

I realized I forgot to put commentary below and I don't want to rerun things:
Each for loop here is for a different purity, 0.98, 0.7, or 0.4.

The parameters of the ltc function are:

ltc.producecorrplots(filepath, purity, lower bound of redshift, upper bound of redshift)

There's also a bug where the purity isn't labeled on the plot.

"""
# Out:
# "\n\nI realized I forgot to put commentary below and I don't want to rerun things:\nEach for loop here is for a different purity, 0.98, 0.7, or 0.4.\n\nThe parameters of the ltc function are:\n\nltc.producecorrplots(filepath, purity, lower bound of redshift, upper bound of redshift)\n\nThere's also a bug where the purity isn't labeled on the plot.\n\n"

# %%
for r in range(len(redshifts)-1):
    print(redshifts[r], redshifts[r+1])
    ltc.producecorrplots('/users/kasia/Documents/Fermilab/Code/LSST/LSST_i.fits', 0.98, redshifts[r], redshifts[r+1])
# Out:
# 0.2 0.4
# 0.4 0.6
# 0.6 0.8

# %%
for r in range(len(redshifts)-1):
    print(redshifts[r], redshifts[r+1])
    ltc.producecorrplots('/users/kasia/Documents/Fermilab/Code/LSST_i.fits', 0.7, redshifts[r], redshifts[r+1])
# Out:
# 0.2 0.4
# 0.4 0.6
# 0.6 0.8

# %%
# Purity divided at 0.4
for r in range(len(redshifts)-1):
    print(redshifts[r], redshifts[r+1])
    ltc.producecorrplots('/users/kasia/Documents/Fermilab/Code/LSST_i.fits', 0.4, redshifts[r], redshifts[r+1])
# Out:
# 0.2 0.4
# 0.4 0.6
# 0.6 0.8
