# %%
import numpy as np
import astropy.table

# %%
input = astropy.table.Table.read('/users/kasia/Documents/Fermilab/Code/OneDegSq.fits')
output = astropy.table.Table.read('/users/kasia/Documents/Fermilab/Code/LSST_i.fits')

# %%
output;

# %%
input;

# %%
input.rename_column('galtileid','db_id')

# %%
astropy.table.join(input, output, join_type = "inner")
# Out:
# <Table length=45289>
#    db_id            ra              dec        ...    hsm_e1       hsm_e2
#    int64         float64          float64      ...   float32      float32
# ------------ ---------------- ---------------- ... ------------ ------------
#   2200000157  0.0149676799393  0.0429675988853 ...   0.24412523  0.043967623
#   2200002540  0.0396176576587 -0.0342307984829 ...   0.69502884   0.55624014
#   2200003406  0.0377796888284     0.1045557037 ...    0.8599374  -0.13934745
#   2200003439  0.0482995510058  0.0564178004861 ...   0.54950845  -0.34375006
#   2200005199  0.0160448551098  0.0970774963498 ...  -0.08158564 -0.017662454
#   2200006079   0.108936429018  0.0614725984633 ...  -0.44775116   -0.1586894
#   2200006482 0.00354135027275  0.0762633010745 ...   0.09882341   -0.4655603
#   2200007260  0.0468925237545 -0.0548657998443 ...  -0.09215707    0.8818809
#   2200007552  0.0791423320738 -0.0565625987947 ...    0.5615493  -0.04918611
# ...

# %%
joined = astropy.table.join(input, output, join_type = "outer")
joined
# Out:
# <Table length=858502>
#    db_id            ra             dec        ...   hsm_e1      hsm_e2
#    int64         float64         float64      ...  float32     float32
# ------------ --------------- ---------------- ... ---------- -----------
#   2200000082  0.280382871625  -0.225252300501 ...         --          --
#   2200000127  0.454564332961 -0.0488336011767 ...         --          --
#   2200000157 0.0149676799393  0.0429675988853 ... 0.24412523 0.043967623
#   2200000219  0.188725709914    0.41345050931 ...         --          --
#   2200000240  0.244941353799  -0.328565508127 ...         --          --
#   2200000262  0.487651586532 -0.0830603018403 ...         --          --
#   2200000328  0.323016881942   0.230253696442 ...         --          --
#   2200000445  0.485592603682  -0.435925602913 ...         --          --
#   2200000534  0.369182348251   0.322383791208 ...         --          --
#   2200000555  0.249027609823  -0.338540107012 ...         --          --
# ...

# %%
"""

Code from astroML example, for reference:

"""

data = joined

#m_max = 17.7
# redshift and magnitude cuts
data = data[data['redshift'] > 0.08]
data = data[data['redshift'] < 0.12]
#data = data[data['petroMag_r'] < m_max]
# RA/DEC cuts
RAmin, RAmax = 140, 220 
DECmin, DECmax = 5, 45
data = data[data['ra'] < RAmax] 
data = data[data['ra'] > RAmin] 
data = data[data['dec'] < DECmax] 
data = data[data['dec'] > DECmin]
ur = data['modelMag_u'] - data['modelMag_r'] 
flag_red = (ur > 2.22)
flag_blue = ~flag_red
data_red = data[flag_red] 
data_blue = data[flag_blue]
print("data size:")
print(" red gals: ", len(data_red)) 
print(" blue gals:", len(data_blue))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-44cdca20567d> in <module>
#       5 data = data[data['z'] > 0.08]
#       6 data = data[data['z'] < 0.12]
# ----> 7 data = data[data['petroMag_r'] < m_max]
#       8 # RA/DEC cuts
#       9 RAmin, RAmax = 140, 220
#
# ~/opt/anaconda3/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1600     def __getitem__(self, item):
#    1601         if isinstance(item, str):
# -> 1602             return self.columns[item]
#    1603         elif isinstance(item, (int, np.integer)):
#    1604             return self.Row(self, item)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#     237         """
#     238         if isinstance(item, str):
# --> 239             return OrderedDict.__getitem__(self, item)
# ...

# %%
joined['modelMag_u']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-9cce188b8a77> in <module>
# ----> 1 joined['modelMag_u']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1600     def __getitem__(self, item):
#    1601         if isinstance(item, str):
# -> 1602             return self.columns[item]
#    1603         elif isinstance(item, (int, np.integer)):
#    1604             return self.Row(self, item)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#     237         """
#     238         if isinstance(item, str):
# --> 239             return OrderedDict.__getitem__(self, item)
#     240         elif isinstance(item, (int, np.integer)):
#     241             return self.values()[item]
#
# KeyError: 'modelMag_u'

# %%
output
# Out:
# <Table length=45289>
#    db_id        grp_id    grp_size ...  hsm_sigm      hsm_e1         hsm_e2
#    int64        int64      int16   ...  float32      float32        float32
# ------------ ------------ -------- ... ---------- -------------- -------------
#   2214322509   2200170838       36 ...  0.6015819     0.13986687    -0.2898496
#   2213221225   2200170838       36 ... 0.36867115    -0.28083616    0.21118678
#   2213832765   2200170838       36 ... 0.36737323     0.00243674   -0.23357214
#   2214602712   2206640565        2 ... 0.36663905    -0.20674483    0.25550604
#   2201272641   2200170838       36 ... 0.47189742     0.76839685   -0.09275026
#   2209286187   2200170838       36 ...  0.8483263      0.1835776  -0.080822386
#   2216818333   2200170838       36 ... 0.35232952   -0.007744919  -0.058648787
#   2208277203   2200170838       36 ...  0.4185837    0.018770117    0.15073346
#   2203591562   2200170838       36 ...   0.401087     0.25719956 -0.0029432753
# ...
