# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import astropy.table
import math

# %%
import pickle

# %%
with open('treecorr_bins0', 'rb') as filehandle:
    treecorr_bins0 = pickle.load(filehandle)
    
with open('treecorr_bins1', 'rb') as filehandle:
    treecorr_bins1 = pickle.load(filehandle)
    
with open('treecorr_corr0', 'rb') as filehandle:
    treecorr_corr0 = pickle.load(filehandle)

with open('treecorr_corr1', 'rb') as filehandle:
    treecorr_corr1 = pickle.load(filehandle)

with open('camb_theta1', 'rb') as filehandle:
    camb_theta1 = pickle.load(filehandle)

with open('camb_w1', 'rb') as filehandle:
    camb_w1 = pickle.load(filehandle)
    
with open('ccl_theta1', 'rb') as filehandle:
    ccl_theta1 = pickle.load(filehandle)

with open('ccl_corr1', 'rb') as filehandle:
    ccl_corr1 = pickle.load(filehandle)

# %%
plt.scatter(math.e**(treecorr_bins0), treecorr_corr0)
#plt.scatter(math.e**(treecorr_bins1), treecorr_corr1)
plt.scatter(camb_theta1[:20], camb_w1[:20])
plt.title("Purity < 0.98 and CAMB")
plt.xlabel(r"Angle $\theta$")
# Out:
# Text(0.5, 0, 'Angle $\\theta$')

# %%
#plt.scatter(math.e**(treecorr_bins0), treecorr_corr0)
plt.scatter(math.e**(treecorr_bins1), treecorr_corr1)
plt.scatter(camb_theta1[:20], camb_w1[:20])
plt.title("Purity > 0.98 and CAMB")
plt.xlabel(r"Angle $\theta$")
# Out:
# Text(0.5, 0, 'Angle $\\theta$')

# %%
plt.scatter(math.e**(treecorr_bins0), treecorr_corr0)
#plt.scatter(math.e**(treecorr_bins1), treecorr_corr1)
plt.scatter(ccl_theta1, ccl_corr1)
plt.title("Purity < 0.98 and CCL")
plt.xlabel(r"Angle $\theta$")
# Out:
# Text(0.5, 0, 'Angle $\\theta$')

# %%
#plt.scatter(math.e**(treecorr_bins0), treecorr_corr0)
plt.scatter(math.e**(treecorr_bins1), treecorr_corr1)
plt.scatter(ccl_theta1, ccl_corr1)
plt.title("Purity > 0.98 and CCL")
plt.xlabel(r"Angle $\theta$")
# Out:
# Text(0.5, 0, 'Angle $\\theta$')
